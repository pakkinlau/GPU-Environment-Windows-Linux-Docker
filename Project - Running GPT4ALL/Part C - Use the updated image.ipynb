# %%
# !sudo docker images
# Out:
# REPOSITORY                  TAG       IMAGE ID       CREATED         SIZE
# pakkinlau/gpt4all-wrapper   latest    d8f6299a5473   2 minutes ago   16.8GB
# pakkinlau/gpt4all-wrapper   <none>    d02965c65fcb   9 hours ago     19.7GB
# hello-world                 latest    d2c94e258dcb   10 months ago   13.3kB

# %% [markdown]
# Gathering the idea of the `docker run`:

# %% [markdown]
# This command is for running jupyter lab:

# %%
# !sudo docker run -p 8888:8888 your-image-name

# %% [markdown]
# This command is for mounting a file into container and replace some files:

# %%
# !sudo docker run -v "$(pwd)/main.py:/app/main.py" pakkinlau/gpt4all-wrapper python /app/main.py

# %% [markdown]
# This command allow me to run jupyter lab in terminal:

# %%
# !jupyter lab --ip=0.0.0.0 --allow-root

# %% [markdown]
# Prompt:
#
# Combine these 3 ideas to give me a suitable `docker run` command.
#
# I need to mount `controller.ipynb` from host PC, and the image also have that file.

# %%
# !sudo docker images
# Out:
# REPOSITORY                  TAG       IMAGE ID       CREATED          SIZE
# pakkinlau/gpt4all-wrapper   latest    d8f6299a5473   14 minutes ago   16.8GB
# pakkinlau/gpt4all-wrapper   <none>    d02965c65fcb   9 hours ago      19.7GB
# hello-world                 latest    d2c94e258dcb   10 months ago    13.3kB

# %% [markdown]
# Suitable prompt:

# %%
# !sudo lsof -i tcp:8888
# Out:
# COMMAND      PID       USER   FD   TYPE  DEVICE SIZE/OFF NODE NAME
# chrome      5867 researcher   32u  IPv4 1120138      0t0  TCP localhost:52084->localhost:8888 (ESTABLISHED)
# chrome      5867 researcher   37u  IPv4 1179085      0t0  TCP localhost:52068->localhost:8888 (ESTABLISHED)
# jupyter-l 267550 researcher    6u  IPv4 1174348      0t0  TCP *:8888 (LISTEN)
# jupyter-l 267550 researcher    7u  IPv4 1205761      0t0  TCP localhost:8888->localhost:52068 (ESTABLISHED)
# jupyter-l 267550 researcher    8u  IPv4 1150523      0t0  TCP localhost:8888->localhost:52084 (ESTABLISHED)

# %%
# !sudo docker run -p 8889:8888 -v "$(pwd)/controller.ipynb:/app/controller.ipynb" pakkinlau/gpt4all-wrapper:latest jupyter lab --ip=0.0.0.0 --allow-root --NotebookApp.token=''
# Out:
# ...
# == CUDA ==
# ...
#
# CUDA Version 12.3.2
#
# Container image Copyright (c) 2016-2023, NVIDIA CORPORATION & AFFILIATES. All rights reserved.
#
# This container image and its contents are governed by the NVIDIA Deep Learning Container License.
# By pulling and using the container, you accept the terms and conditions of this license:
# https://developer.nvidia.com/ngc/nvidia-deep-learning-container-license
#
# A copy of this license is made available in this container at /NGC-DL-CONTAINER-LICENSE for your convenience.
#
# WARNING: The NVIDIA Driver was not detected.  GPU functionality will not be available.
#    Use the NVIDIA Container Toolkit to start this container with GPU support; see
#    https://docs.nvidia.com/datacenter/cloud-native/ .
#
# [I 2024-03-05 16:46:24.855 ServerApp] jupyter_lsp | extension was successfully linked.
# [I 2024-03-05 16:46:24.857 ServerApp] jupyter_server_terminals | extension was successfully linked.
# ...

# %%
# !sudo docker run --network host -v "$(pwd)/controller.ipynb:/app/controller.ipynb" pakkinlau/gpt4all-wrapper:latest jupyter lab --ip=0.0.0.0 --allow-root --NotebookApp.token=''
# Out:
# ...
# == CUDA ==
# ...
#
# CUDA Version 12.3.2
#
# Container image Copyright (c) 2016-2023, NVIDIA CORPORATION & AFFILIATES. All rights reserved.
#
# This container image and its contents are governed by the NVIDIA Deep Learning Container License.
# By pulling and using the container, you accept the terms and conditions of this license:
# https://developer.nvidia.com/ngc/nvidia-deep-learning-container-license
#
# A copy of this license is made available in this container at /NGC-DL-CONTAINER-LICENSE for your convenience.
#
# WARNING: The NVIDIA Driver was not detected.  GPU functionality will not be available.
#    Use the NVIDIA Container Toolkit to start this container with GPU support; see
#    https://docs.nvidia.com/datacenter/cloud-native/ .
#
# [I 2024-03-05 16:46:41.088 ServerApp] jupyter_lsp | extension was successfully linked.
# [I 2024-03-05 16:46:41.090 ServerApp] jupyter_server_terminals | extension was successfully linked.
# ...

# %% [markdown]
# After running the image, I am satisfited with that. So I push this image:

# %%
# !sudo docker login
# Out:
# Authenticating with existing credentials...
# WARNING! Your password will be stored unencrypted in /root/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded

# %%
# !sudo docker push pakkinlau/gpt4all-wrapper:latest
# Out:
# The push refers to repository [docker.io/pakkinlau/gpt4all-wrapper]
#
# f148028c: Preparing
# dde34235: Preparing
# f6ce846a: Preparing
# 4c60a571: Preparing
# a9fead2d: Preparing
# 1a1c8422: Preparing
# 3ccd0e61: Preparing
# b17d2686: Preparing
# 7b849c2d: Preparing
# 2ba094e1: Preparing
# f939e8ef: Preparing
# 20082ab6: Preparing
# 89477cd0: Preparing
# a508ec30: Preparing
# 0a27585a: Preparing
# 852fcfd3: Preparing
# 793a3432: Preparing
# 54a69fbf: Preparing
# 5d3b1182: Preparing
# c60a571: Pushed   7.373GB/7.373GBPushing  2.636GB/5.185GBPushing  2.594GB/7.373GBlatest: digest: sha256:007240933046f1e489aab9c63d87cfb72f0758a755eedd8b80479966721b20a7 size: 4525

# %% [markdown]
# Total time spent: 20 min 17sec
