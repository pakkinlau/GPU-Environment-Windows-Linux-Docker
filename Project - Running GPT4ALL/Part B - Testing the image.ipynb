# %% [markdown]
# ## Part 1: Test current image

# %%
# !sudo docker images
# Out:
# REPOSITORY                  TAG       IMAGE ID       CREATED         SIZE
# pakkinlau/gpt4all-wrapper   latest    d02965c65fcb   6 hours ago     19.7GB
# hello-world                 latest    d2c94e258dcb   10 months ago   13.3kB

# %% [markdown]
# To run `main.py` from the host system, (that is expected will be changed a lot), into the container (we expect docker image should be changed less frequent), we would mount the file.
#
# So we have the following command:
#
# `!sudo docker run -v $(pwd)/main.py:/app/main.py pakkinlau/gpt4all-wrapper python /app/main.py`
#
# - `-v "$(pwd)/main.py:/app/main.py"`: This option mounts the `main.py` file from the currend director `$(pwd)`, which is a shell command that outputs current directory, into the container at the location `/app/main.py`. Remark: This argument must be quoted, otherwise it would return uppercase / whitespace error when docker is trying to comprehend the location.
#
# - `pakkinlau/gpt4all-wrapper` is the name of th Docker image we want to run.
#
# - (Optional) `python /app/main.py`: This part is an optional argument that tells docker what to do after mounting the file into the target location in the container.

# %% [markdown]
# The overall effect for this `docker run` command is:
# - Replace `main.py` in the image, to be the `main.py` that we provided in first argument.
# - Container will run `/app/main.py` with python after mounting the host system's main.py.

# %%
# !sudo docker run -v "$(pwd)/main.py:/app/main.py" pakkinlau/gpt4all-wrapper python /app/main.py
# Out:
# ==========
# == CUDA ==
# ==========
#
# CUDA Version 12.3.2
#
# Container image Copyright (c) 2016-2023, NVIDIA CORPORATION & AFFILIATES. All rights reserved.
#
# This container image and its contents are governed by the NVIDIA Deep Learning Container License.
# By pulling and using the container, you accept the terms and conditions of this license:
# https://developer.nvidia.com/ngc/nvidia-deep-learning-container-license
#
# A copy of this license is made available in this container at /NGC-DL-CONTAINER-LICENSE for your convenience.
#
# WARNING: The NVIDIA Driver was not detected.  GPU functionality will not be available.
#    Use the NVIDIA Container Toolkit to start this container with GPU support; see
#    https://docs.nvidia.com/datacenter/cloud-native/ .
#
# Traceback (most recent call last):
#   File "/app/main.py", line 2, in <module>
#     model = GPT4All("./models/nous-hermes-llama2-13b.Q4_0.gguf")
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/.pyenv/versions/3.11.7/lib/python3.11/site-packages/gpt4all/gpt4all.py", line 101, in __init__
#     self.config: ConfigType = self.retrieve_model(model_name, model_path=model_path, allow_download=allow_download, verbose=verbose)
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/.pyenv/versions/3.11.7/lib/python3.11/site-packages/gpt4all/gpt4all.py", line 191, in retrieve_model
#     config["path"] = GPT4All.download_model(model_filename, model_path, verbose=verbose, url=url)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/.pyenv/versions/3.11.7/lib/python3.11/site-packages/gpt4all/gpt4all.py", line 238, in download_model
#     response = make_request()
#                ^^^^^^^^^^^^^^
#   File "/root/.pyenv/versions/3.11.7/lib/python3.11/site-packages/gpt4all/gpt4all.py", line 233, in make_request
#     raise ValueError(f'Request failed: HTTP {response.status_code} {response.reason}')
# ValueError: Request failed: HTTP 404 Not Found

# %%
# !pwd
# Out:
# /home/researcher/Desktop/Project folder/EuropeChinaBigData/LLM setup procedure/Project - Running GPT4ALL

# %% [markdown]
# Analyzing error:
#
# Print current directory tree:

# %%
import os

def print_tree(directory, indent=''):
    files = os.listdir(directory)
    files.sort()  # Sort files alphabetically

    tree_string = ""  # Variable to store the tree string

    for file in files:
        path = os.path.join(directory, file)
        if os.path.isfile(path):
            # Append file name with proper indentation to the tree string
            tree_string += f"{indent}|-- {file}\n"
        elif os.path.isdir(path):
            # Append directory name with proper indentation to the tree string
            tree_string += f"{indent}|-- {file}/\n"
            # Recursive call with increased indentation
            tree_string += print_tree(path, indent + "|   ")

    return tree_string

# Generate the tree string
root_dir = os.getcwd()
tree_string = print_tree(root_dir)

# Print the tree string to the console
print(tree_string)
# Out:
# |-- Dockerfile
# |-- Part A - Write GPT4ALL-wrapper.ipynb
# |-- Part B - Testing the image.ipynb
# |-- check_internet.py
# |-- controller.ipynb
# |-- main.py
# |-- models/
# |   |-- nous-hermes-llama2-13b.Q4_0.gguf

# %% [markdown]
# To inspect the docker image:

# %% [markdown]
# (Run this in terminal, due to its interactive nature)
#
# - `-it`: this option tells Docker to allocate a pseudo-TTY and keep STDIN open.
# - `-rm`: remove the container when exiting the container's shell.
# - `--name temp-container` this option assigns a name to the running container, making it easier to reference.
# - `bash`: this is the command that will be run inside the new container. `bash` is starting a bash shell.

# %%
# !sudo docker run -it --rm --name temp-container pakkinlau/gpt4all-wrapper bash

# %%
root@da26a9e2e8f2:/app# ls -la
total 28
drwxr-xr-x 1 root root 4096 Mar  5 07:40  .
drwxr-xr-x 1 root root 4096 Mar  5 14:24  ..
-rw-rw-r-- 1 root root 3366 Mar  5 07:40  Dockerfile
-rw-rw-r-- 1 root root 6356 Mar  5 07:13 'Run GPT4ALL.ipynb'
-rw-rw-r-- 1 root root  211 Mar  4 23:03  main.py
drwxrwxr-x 2 root root 4096 Mar  4 21:29  models
root@da26a9e2e8f2:/app# ls -la /app/models/
total 7193432
drwxrwxr-x 2 root root       4096 Mar  4 21:29 .
drwxr-xr-x 1 root root       4096 Mar  5 07:40 ..
-rw-rw-r-- 1 root root 7366062080 Mar  4 20:50 nous-hermes-llama2-13b.Q4_0.gguf
root@da26a9e2e8f2:/app#

# %% [markdown]
# There are a few of possible error:
#
# Internet access problem:
# - We can check it by using the image to run another python script that access google.com
#
# Permission problem:
# - In bash, modify them with `chmod` and `chown`

# %% [markdown]
# ## Part 2: Updating current image

# %%
# !sudo docker images
# Out:
# REPOSITORY                  TAG       IMAGE ID       CREATED         SIZE
# pakkinlau/gpt4all-wrapper   latest    d02965c65fcb   7 hours ago     19.7GB
# hello-world                 latest    d2c94e258dcb   10 months ago   13.3kB

# %% [markdown]
# After completed editing the project folder and Dockerfile, run `docker build` to update the image

# %%
# !sudo docker build -t pakkinlau/gpt4all-wrapper .

# %% [markdown]
# ## Part 3: New proposal - Running jupyter notebooks inside container, commit changes to the image, after changing the container

# %% [markdown]
# When we use `docker commit` to create a new image, Docker uses a layered filesystem. This means the new image will share layers with the old image, only the changes that have been made in the container will add addition storage usage.
#
# To see the shared layer, and how much space is actually being used, `docker history image_name:tag`.
#
# If deleting old image, Docker's layered file system ensures that only the unique layersof the old images are removed.
#
# We will discuss how to commit image changes below:

# %% [markdown]
# Say the container is still running. We need to do the following steps:
#
# - 1. Find the contaienr ID: `docker ps` or `docker ps -a`
#
# - 2. Commit the container: `docker commit container_id_or_name new_image_name:tag`
#
# - 3. stop the container: `docker stop container_id_or_name`
# - 4. Run a new container from the new image: `docker run -p 8888:8888 new_image_name:tag`

# %% [markdown]
# ## Part 4 Implementing the change

# %% [markdown]
# Now, I added `controller.ipynb` into the project folder:

# %%
# Print the tree string to the console
print(tree_string)
# Out:
# |-- Dockerfile
# |-- Part A - Write GPT4ALL-wrapper.ipynb
# |-- Part B - Testing the image.ipynb
# |-- check_internet.py
# |-- controller.ipynb
# |-- main.py
# |-- models/
# |   |-- nous-hermes-llama2-13b.Q4_0.gguf

# %% [markdown]
# ## Part 5: Short term maintenance: `docker commit`

# %% [markdown]
# Implement the follwowing changes on the docker image:
#
# - Install python 3.11
# - Use virtual environemtn to keep track on installed packages
# - Run jupyter lab at the end to make a controller environment
# - Potentially use `docker commit` to update the image
# - Potentially use `pip freeze > requirements.txt` to make the changes more tracable.

# %% [markdown]
# The following are the major steps of updating a docker image:

# %%
# step 1: update requirements.txt
# !pip freeze > requirements.txt

# %%
# step 2: copy the new requirements.txt to the host machine.
# !sudo docker cp my_container:/path/to/requirements.txt /path/on/host/machine/requirements.txt

# %% [markdown]
# Finally, to commit a change
#
# - `abc123` container ID. Use `docker ps` at the time of running the docker image to get to know of that.
# - `my-updated-image`: replace it with the tag of the image. For this project, it is `pakkinlau/gpt4all-wrapper`.
# - `:v20`: `v20` indicates the custom version tag. It is `latest` is the default version tag, for the last tag that maps to the image.

# %%
# !sudo docker commit -m "Installed new_package" abc123 my-updated-image:v20

# %% [markdown]
# Inside Dockerfile, we will have the follwoing lines that update the requirements.txt inside the image:
#
# ```Dockerfile
# COPY requirements.txt /app/requirements.txt
# RUN pip install --no-cache-dir -r /app/requirements.txt
# ```

# %% [markdown]
# ## Part 6 - Long term maintenance - `docker build`

# %% [markdown]
# To create/update, we use the following command:

# %%
# !sudo docker build -t pakkinlau/gpt4all-wrapper .
# Out:
# [+] Building 0.0s (0/1)                                          docker:default
# [+] Building 0.2s (1/2)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  0.2s
# [+] Building 0.3s (1/2)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  0.3s
# [+] Building 0.5s (1/2)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  0.5s
# [+] Building 0.6s (1/2)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  0.6s
# [+] Building 0.8s (1/2)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  0.8s
# [+] Building 0.8s (1/3)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  0.8s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
# [+] Building 1.0s (2/3)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  1.0s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
# [+] Building 1.1s (2/3)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  1.1s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
# [+] Building 1.3s (2/3)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  1.3s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
# [+] Building 1.4s (2/3)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  1.4s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
# [+] Building 1.6s (2/3)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  1.6s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
# [+] Building 1.7s (2/3)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  1.7s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
# [+] Building 1.9s (2/3)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  1.9s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
# [+] Building 2.0s (2/3)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  2.0s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
# [+] Building 2.0s (3/3)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  2.0s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
# [+] Building 2.3s (6/16)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  2.0s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [ 1/11] FROM docker.io/nvidia/cuda:12.3.2-cudnn9-runtime-ubunt  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 7.29MB                                        0.1s
#  => [ 2/11] RUN apt-get update && apt-get install -y --no-install-recomme  0.2s
# [+] Building 2.4s (6/16)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  2.0s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [ 1/11] FROM docker.io/nvidia/cuda:12.3.2-cudnn9-runtime-ubunt  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 7.29MB                                        0.1s
#  => [ 2/11] RUN apt-get update && apt-get install -y --no-install-recomme  0.3s
#  => => # Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2
#  => => # 204/x86_64  InRelease [1581 B]
# [+] Building 2.6s (6/16)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  2.0s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [ 1/11] FROM docker.io/nvidia/cuda:12.3.2-cudnn9-runtime-ubunt  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 7.29MB                                        0.1s
#  => [ 2/11] RUN apt-get update && apt-get install -y --no-install-recomme  0.5s
#  => => # Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2
#  => => # 204/x86_64  InRelease [1581 B]
#  => => # Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2
#  => => # 204/x86_64  Packages [713 kB]
# [+] Building 2.7s (6/16)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  2.0s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [ 1/11] FROM docker.io/nvidia/cuda:12.3.2-cudnn9-runtime-ubunt  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 7.29MB                                        0.1s
#  => [ 2/11] RUN apt-get update && apt-get install -y --no-install-recomme  0.7s
#  => => # Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2
#  => => # 204/x86_64  InRelease [1581 B]
#  => => # Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2
#  => => # 204/x86_64  Packages [713 kB]
# [+] Building 2.9s (6/16)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  2.0s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [ 1/11] FROM docker.io/nvidia/cuda:12.3.2-cudnn9-runtime-ubunt  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 7.29MB                                        0.1s
#  => [ 2/11] RUN apt-get update && apt-get install -y --no-install-recomme  0.8s
#  => => # Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2
#  => => # 204/x86_64  InRelease [1581 B]
#  => => # Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2
#  => => # 204/x86_64  Packages [713 kB]
# [+] Building 2.9s (6/16)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  2.0s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [ 1/11] FROM docker.io/nvidia/cuda:12.3.2-cudnn9-runtime-ubunt  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 7.29MB                                        0.1s
#  => [ 2/11] RUN apt-get update && apt-get install -y --no-install-recomme  0.8s
#  => => # Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2
#  => => # 204/x86_64  InRelease [1581 B]
#  => => # Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2
#  => => # 204/x86_64  Packages [713 kB]
#  => => # Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [110
#  => => # kB]
# [+] Building 3.1s (6/16)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  2.0s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [ 1/11] FROM docker.io/nvidia/cuda:12.3.2-cudnn9-runtime-ubunt  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 7.29MB                                        0.1s
#  => [ 2/11] RUN apt-get update && apt-get install -y --no-install-recomme  1.0s
#  => => # 204/x86_64  InRelease [1581 B]
#  => => # Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2
#  => => # 204/x86_64  Packages [713 kB]
#  => => # Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [110
#  => => # kB]
#  => => # Get:4 http://archive.ubuntu.com/ubuntu jammy InRelease [270 kB]
# [+] Building 3.2s (6/16)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  2.0s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [ 1/11] FROM docker.io/nvidia/cuda:12.3.2-cudnn9-runtime-ubunt  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 7.29MB                                        0.1s
#  => [ 2/11] RUN apt-get update && apt-get install -y --no-install-recomme  1.2s
#  => => # 204/x86_64  InRelease [1581 B]
#  => => # Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2
#  => => # 204/x86_64  Packages [713 kB]
#  => => # Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [110
#  => => # kB]
#  => => # Get:4 http://archive.ubuntu.com/ubuntu jammy InRelease [270 kB]
# [+] Building 3.4s (6/16)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  2.0s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [ 1/11] FROM docker.io/nvidia/cuda:12.3.2-cudnn9-runtime-ubunt  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 7.29MB                                        0.1s
#  => [ 2/11] RUN apt-get update && apt-get install -y --no-install-recomme  1.3s
#  => => # 204/x86_64  InRelease [1581 B]
#  => => # Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2
#  => => # 204/x86_64  Packages [713 kB]
#  => => # Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [110
#  => => # kB]
#  => => # Get:4 http://archive.ubuntu.com/ubuntu jammy InRelease [270 kB]
# [+] Building 3.5s (6/16)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  2.0s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [ 1/11] FROM docker.io/nvidia/cuda:12.3.2-cudnn9-runtime-ubunt  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 7.29MB                                        0.1s
#  => [ 2/11] RUN apt-get update && apt-get install -y --no-install-recomme  1.5s
#  => => # 204/x86_64  InRelease [1581 B]
#  => => # Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2
#  => => # 204/x86_64  Packages [713 kB]
#  => => # Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [110
#  => => # kB]
#  => => # Get:4 http://archive.ubuntu.com/ubuntu jammy InRelease [270 kB]
# [+] Building 3.7s (6/16)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  2.0s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [ 1/11] FROM docker.io/nvidia/cuda:12.3.2-cudnn9-runtime-ubunt  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 7.29MB                                        0.1s
#  => [ 2/11] RUN apt-get update && apt-get install -y --no-install-recomme  1.6s
#  => => # 204/x86_64  InRelease [1581 B]
#  => => # Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2
#  => => # 204/x86_64  Packages [713 kB]
#  => => # Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [110
#  => => # kB]
#  => => # Get:4 http://archive.ubuntu.com/ubuntu jammy InRelease [270 kB]
# [+] Building 3.8s (6/16)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  2.0s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [ 1/11] FROM docker.io/nvidia/cuda:12.3.2-cudnn9-runtime-ubunt  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 7.29MB                                        0.1s
#  => [ 2/11] RUN apt-get update && apt-get install -y --no-install-recomme  1.8s
#  => => # 204/x86_64  InRelease [1581 B]
#  => => # Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2
#  => => # 204/x86_64  Packages [713 kB]
#  => => # Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [110
#  => => # kB]
#  => => # Get:4 http://archive.ubuntu.com/ubuntu jammy InRelease [270 kB]
# [+] Building 3.9s (6/16)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  2.0s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [ 1/11] FROM docker.io/nvidia/cuda:12.3.2-cudnn9-runtime-ubunt  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 7.29MB                                        0.1s
#  => [ 2/11] RUN apt-get update && apt-get install -y --no-install-recomme  1.8s
#  => => # 204/x86_64  Packages [713 kB]
#  => => # Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [110
#  => => # kB]
#  => => # Get:4 http://archive.ubuntu.com/ubuntu jammy InRelease [270 kB]
#  => => # Get:5 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd6
#  => => # 4 Packages [44.6 kB]
# [+] Building 4.1s (6/16)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  2.0s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [ 1/11] FROM docker.io/nvidia/cuda:12.3.2-cudnn9-runtime-ubunt  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 7.29MB                                        0.1s
#  => [ 2/11] RUN apt-get update && apt-get install -y --no-install-recomme  2.0s
#  => => # 204/x86_64  Packages [713 kB]
#  => => # Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [110
#  => => # kB]
#  => => # Get:4 http://archive.ubuntu.com/ubuntu jammy InRelease [270 kB]
#  => => # Get:5 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd6
#  => => # 4 Packages [44.6 kB]
# [+] Building 4.2s (6/16)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  2.0s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [ 1/11] FROM docker.io/nvidia/cuda:12.3.2-cudnn9-runtime-ubunt  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 7.29MB                                        0.1s
#  => [ 2/11] RUN apt-get update && apt-get install -y --no-install-recomme  2.1s
#  => => # 204/x86_64  Packages [713 kB]
#  => => # Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [110
#  => => # kB]
#  => => # Get:4 http://archive.ubuntu.com/ubuntu jammy InRelease [270 kB]
#  => => # Get:5 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd6
#  => => # 4 Packages [44.6 kB]
# [+] Building 4.3s (6/16)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  2.0s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [ 1/11] FROM docker.io/nvidia/cuda:12.3.2-cudnn9-runtime-ubunt  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 7.29MB                                        0.1s
#  => [ 2/11] RUN apt-get update && apt-get install -y --no-install-recomme  2.2s
#  => => # Get:5 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd6
#  => => # 4 Packages [44.6 kB]
#  => => # Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB
#  => => # ]
#  => => # Get:7 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Pack
#  => => # ages [1522 kB]
# [+] Building 4.5s (6/16)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  2.0s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [ 1/11] FROM docker.io/nvidia/cuda:12.3.2-cudnn9-runtime-ubunt  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 7.29MB                                        0.1s
#  => [ 2/11] RUN apt-get update && apt-get install -y --no-install-recomme  2.4s
#  => => # Get:5 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd6
#  => => # 4 Packages [44.6 kB]
#  => => # Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB
#  => => # ]
#  => => # Get:7 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Pack
#  => => # ages [1522 kB]
# [+] Building 4.6s (6/16)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  2.0s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [ 1/11] FROM docker.io/nvidia/cuda:12.3.2-cudnn9-runtime-ubunt  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 7.29MB                                        0.1s
#  => [ 2/11] RUN apt-get update && apt-get install -y --no-install-recomme  2.5s
#  => => # Get:5 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd6
#  => => # 4 Packages [44.6 kB]
#  => => # Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB
#  => => # ]
#  => => # Get:7 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Pack
#  => => # ages [1522 kB]
# [+] Building 4.8s (6/16)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  2.0s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [ 1/11] FROM docker.io/nvidia/cuda:12.3.2-cudnn9-runtime-ubunt  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 7.29MB                                        0.1s
#  => [ 2/11] RUN apt-get update && apt-get install -y --no-install-recomme  2.7s
#  => => # Get:5 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd6
#  => => # 4 Packages [44.6 kB]
#  => => # Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB
#  => => # ]
#  => => # Get:7 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Pack
#  => => # ages [1522 kB]
# [+] Building 4.9s (6/16)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  2.0s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [ 1/11] FROM docker.io/nvidia/cuda:12.3.2-cudnn9-runtime-ubunt  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 7.29MB                                        0.1s
#  => [ 2/11] RUN apt-get update && apt-get install -y --no-install-recomme  2.8s
#  => => # Get:5 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd6
#  => => # 4 Packages [44.6 kB]
#  => => # Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB
#  => => # ]
#  => => # Get:7 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Pack
#  => => # ages [1522 kB]
# [+] Building 5.1s (6/16)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  2.0s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [ 1/11] FROM docker.io/nvidia/cuda:12.3.2-cudnn9-runtime-ubunt  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 7.29MB                                        0.1s
#  => [ 2/11] RUN apt-get update && apt-get install -y --no-install-recomme  3.0s
#  => => # Get:5 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd6
#  => => # 4 Packages [44.6 kB]
#  => => # Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB
#  => => # ]
#  => => # Get:7 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Pack
#  => => # ages [1522 kB]
# [+] Building 5.2s (6/16)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  2.0s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [ 1/11] FROM docker.io/nvidia/cuda:12.3.2-cudnn9-runtime-ubunt  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 7.29MB                                        0.1s
#  => [ 2/11] RUN apt-get update && apt-get install -y --no-install-recomme  3.1s
#  => => # Get:5 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd6
#  => => # 4 Packages [44.6 kB]
#  => => # Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB
#  => => # ]
#  => => # Get:7 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Pack
#  => => # ages [1522 kB]
# [+] Building 5.4s (6/16)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  2.0s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [ 1/11] FROM docker.io/nvidia/cuda:12.3.2-cudnn9-runtime-ubunt  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 7.29MB                                        0.1s
#  => [ 2/11] RUN apt-get update && apt-get install -y --no-install-recomme  3.3s
#  => => # Get:5 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd6
#  => => # 4 Packages [44.6 kB]
#  => => # Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB
#  => => # ]
#  => => # Get:7 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Pack
#  => => # ages [1522 kB]
# [+] Building 5.4s (6/16)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  2.0s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [ 1/11] FROM docker.io/nvidia/cuda:12.3.2-cudnn9-runtime-ubunt  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 7.29MB                                        0.1s
#  => [ 2/11] RUN apt-get update && apt-get install -y --no-install-recomme  3.3s
#  => => # Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB
#  => => # ]
#  => => # Get:7 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Pack
#  => => # ages [1522 kB]
#  => => # Get:8 http://security.ubuntu.com/ubuntu jammy-security/universe amd64
#  => => # Packages [1074 kB]
# [+] Building 5.5s (6/16)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  2.0s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [ 1/11] FROM docker.io/nvidia/cuda:12.3.2-cudnn9-runtime-ubunt  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 7.29MB                                        0.1s
#  => [ 2/11] RUN apt-get update && apt-get install -y --no-install-recomme  3.5s
#  => => # Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB
#  => => # ]
#  => => # Get:7 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Pack
#  => => # ages [1522 kB]
#  => => # Get:8 http://security.ubuntu.com/ubuntu jammy-security/universe amd64
#  => => # Packages [1074 kB]
# [+] Building 5.6s (6/16)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  2.0s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [ 1/11] FROM docker.io/nvidia/cuda:12.3.2-cudnn9-runtime-ubunt  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 7.29MB                                        0.1s
#  => [ 2/11] RUN apt-get update && apt-get install -y --no-install-recomme  3.5s
#  => => # Get:7 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Pack
#  => => # ages [1522 kB]
#  => => # Get:8 http://security.ubuntu.com/ubuntu jammy-security/universe amd64
#  => => # Packages [1074 kB]
#  => => # Get:9 http://security.ubuntu.com/ubuntu jammy-security/restricted amd6
#  => => # 4 Packages [1894 kB]
# [+] Building 5.7s (6/16)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  2.0s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [ 1/11] FROM docker.io/nvidia/cuda:12.3.2-cudnn9-runtime-ubunt  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 7.29MB                                        0.1s
#  => [ 2/11] RUN apt-get update && apt-get install -y --no-install-recomme  3.6s
#  => => # Get:7 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Pack
#  => => # ages [1522 kB]
#  => => # Get:8 http://security.ubuntu.com/ubuntu jammy-security/universe amd64
#  => => # Packages [1074 kB]
#  => => # Get:9 http://security.ubuntu.com/ubuntu jammy-security/restricted amd6
#  => => # 4 Packages [1894 kB]
# [+] Building 5.9s (6/16)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  2.0s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [ 1/11] FROM docker.io/nvidia/cuda:12.3.2-cudnn9-runtime-ubunt  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 7.29MB                                        0.1s
#  => [ 2/11] RUN apt-get update && apt-get install -y --no-install-recomme  3.8s
#  => => # Get:7 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Pack
#  => => # ages [1522 kB]
#  => => # Get:8 http://security.ubuntu.com/ubuntu jammy-security/universe amd64
#  => => # Packages [1074 kB]
#  => => # Get:9 http://security.ubuntu.com/ubuntu jammy-security/restricted amd6
#  => => # 4 Packages [1894 kB]
# [+] Building 6.0s (6/16)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  2.0s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [ 1/11] FROM docker.io/nvidia/cuda:12.3.2-cudnn9-runtime-ubunt  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 7.29MB                                        0.1s
#  => [ 2/11] RUN apt-get update && apt-get install -y --no-install-recomme  3.9s
#  => => # Get:7 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Pack
#  => => # ages [1522 kB]
#  => => # Get:8 http://security.ubuntu.com/ubuntu jammy-security/universe amd64
#  => => # Packages [1074 kB]
#  => => # Get:9 http://security.ubuntu.com/ubuntu jammy-security/restricted amd6
#  => => # 4 Packages [1894 kB]
# [+] Building 6.2s (6/16)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  2.0s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [ 1/11] FROM docker.io/nvidia/cuda:12.3.2-cudnn9-runtime-ubunt  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 7.29MB                                        0.1s
#  => [ 2/11] RUN apt-get update && apt-get install -y --no-install-recomme  4.1s
#  => => # Get:7 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Pack
#  => => # ages [1522 kB]
#  => => # Get:8 http://security.ubuntu.com/ubuntu jammy-security/universe amd64
#  => => # Packages [1074 kB]
#  => => # Get:9 http://security.ubuntu.com/ubuntu jammy-security/restricted amd6
#  => => # 4 Packages [1894 kB]
# [+] Building 6.3s (6/16)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  2.0s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [ 1/11] FROM docker.io/nvidia/cuda:12.3.2-cudnn9-runtime-ubunt  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 7.29MB                                        0.1s
#  => [ 2/11] RUN apt-get update && apt-get install -y --no-install-recomme  4.2s
#  => => # Get:7 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Pack
#  => => # ages [1522 kB]
#  => => # Get:8 http://security.ubuntu.com/ubuntu jammy-security/universe amd64
#  => => # Packages [1074 kB]
#  => => # Get:9 http://security.ubuntu.com/ubuntu jammy-security/restricted amd6
#  => => # 4 Packages [1894 kB]
# [+] Building 6.5s (6/16)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  2.0s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [ 1/11] FROM docker.io/nvidia/cuda:12.3.2-cudnn9-runtime-ubunt  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 7.29MB                                        0.1s
#  => [ 2/11] RUN apt-get update && apt-get install -y --no-install-recomme  4.4s
#  => => # Get:7 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Pack
#  => => # ages [1522 kB]
#  => => # Get:8 http://security.ubuntu.com/ubuntu jammy-security/universe amd64
#  => => # Packages [1074 kB]
#  => => # Get:9 http://security.ubuntu.com/ubuntu jammy-security/restricted amd6
#  => => # 4 Packages [1894 kB]
# [+] Building 6.6s (6/16)                                         docker:default
# ...
# [+] Building 237.5s (16/17)                                      docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  2.0s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [ 1/11] FROM docker.io/nvidia/cuda:12.3.2-cudnn9-runtime-ubunt  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 7.29MB                                        0.1s
#  => [ 2/11] RUN apt-get update && apt-get install -y --no-install-recomm  77.0s
#  => [ 3/11] RUN python3.11 -m venv /opt/venv                               2.0s
#  => [ 4/11] RUN pip install --no-cache-dir --upgrade pip                   1.6s
#  => [ 5/11] RUN pip install --no-cache-dir torch torchvision torchaudio  120.7s
#  => [ 6/11] RUN pip install --no-cache-dir jupyter notebook jupyterlab    13.2s
#  => [ 7/11] WORKDIR /app                                                   0.0s
#  => [ 8/11] COPY . /app                                                    6.7s
#  => [ 9/11] RUN pip3 install gpt4all                                       2.1s
#  => [10/11] COPY requirements.txt /app/requirements.txt                    0.0s
#  => [11/11] RUN pip install --no-cache-dir -r /app/requirements.txt        1.3s
#  => exporting to image                                                    10.7s
#  => => exporting layers                                                   10.7s
# [+] Building 237.6s (16/17)                                      docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  2.0s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [ 1/11] FROM docker.io/nvidia/cuda:12.3.2-cudnn9-runtime-ubunt  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 7.29MB                                        0.1s
#  => [ 2/11] RUN apt-get update && apt-get install -y --no-install-recomm  77.0s
#  => [ 3/11] RUN python3.11 -m venv /opt/venv                               2.0s
#  => [ 4/11] RUN pip install --no-cache-dir --upgrade pip                   1.6s
#  => [ 5/11] RUN pip install --no-cache-dir torch torchvision torchaudio  120.7s
#  => [ 6/11] RUN pip install --no-cache-dir jupyter notebook jupyterlab    13.2s
#  => [ 7/11] WORKDIR /app                                                   0.0s
#  => [ 8/11] COPY . /app                                                    6.7s
#  => [ 9/11] RUN pip3 install gpt4all                                       2.1s
#  => [10/11] COPY requirements.txt /app/requirements.txt                    0.0s
#  => [11/11] RUN pip install --no-cache-dir -r /app/requirements.txt        1.3s
#  => exporting to image                                                    10.8s
#  => => exporting layers                                                   10.8s
# [+] Building 237.8s (16/17)                                      docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  2.0s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [ 1/11] FROM docker.io/nvidia/cuda:12.3.2-cudnn9-runtime-ubunt  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 7.29MB                                        0.1s
#  => [ 2/11] RUN apt-get update && apt-get install -y --no-install-recomm  77.0s
#  => [ 3/11] RUN python3.11 -m venv /opt/venv                               2.0s
#  => [ 4/11] RUN pip install --no-cache-dir --upgrade pip                   1.6s
#  => [ 5/11] RUN pip install --no-cache-dir torch torchvision torchaudio  120.7s
#  => [ 6/11] RUN pip install --no-cache-dir jupyter notebook jupyterlab    13.2s
#  => [ 7/11] WORKDIR /app                                                   0.0s
#  => [ 8/11] COPY . /app                                                    6.7s
#  => [ 9/11] RUN pip3 install gpt4all                                       2.1s
#  => [10/11] COPY requirements.txt /app/requirements.txt                    0.0s
#  => [11/11] RUN pip install --no-cache-dir -r /app/requirements.txt        1.3s
#  => exporting to image                                                    11.0s
#  => => exporting layers                                                   11.0s
# [+] Building 237.9s (16/17)                                      docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  2.0s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [ 1/11] FROM docker.io/nvidia/cuda:12.3.2-cudnn9-runtime-ubunt  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 7.29MB                                        0.1s
#  => [ 2/11] RUN apt-get update && apt-get install -y --no-install-recomm  77.0s
#  => [ 3/11] RUN python3.11 -m venv /opt/venv                               2.0s
#  => [ 4/11] RUN pip install --no-cache-dir --upgrade pip                   1.6s
#  => [ 5/11] RUN pip install --no-cache-dir torch torchvision torchaudio  120.7s
#  => [ 6/11] RUN pip install --no-cache-dir jupyter notebook jupyterlab    13.2s
#  => [ 7/11] WORKDIR /app                                                   0.0s
#  => [ 8/11] COPY . /app                                                    6.7s
#  => [ 9/11] RUN pip3 install gpt4all                                       2.1s
#  => [10/11] COPY requirements.txt /app/requirements.txt                    0.0s
#  => [11/11] RUN pip install --no-cache-dir -r /app/requirements.txt        1.3s
#  => exporting to image                                                    11.1s
#  => => exporting layers                                                   11.1s
# [+] Building 238.1s (16/17)                                      docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  2.0s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [ 1/11] FROM docker.io/nvidia/cuda:12.3.2-cudnn9-runtime-ubunt  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 7.29MB                                        0.1s
#  => [ 2/11] RUN apt-get update && apt-get install -y --no-install-recomm  77.0s
#  => [ 3/11] RUN python3.11 -m venv /opt/venv                               2.0s
#  => [ 4/11] RUN pip install --no-cache-dir --upgrade pip                   1.6s
#  => [ 5/11] RUN pip install --no-cache-dir torch torchvision torchaudio  120.7s
#  => [ 6/11] RUN pip install --no-cache-dir jupyter notebook jupyterlab    13.2s
#  => [ 7/11] WORKDIR /app                                                   0.0s
#  => [ 8/11] COPY . /app                                                    6.7s
#  => [ 9/11] RUN pip3 install gpt4all                                       2.1s
#  => [10/11] COPY requirements.txt /app/requirements.txt                    0.0s
#  => [11/11] RUN pip install --no-cache-dir -r /app/requirements.txt        1.3s
#  => exporting to image                                                    11.3s
#  => => exporting layers                                                   11.3s
# [+] Building 238.2s (16/17)                                      docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  2.0s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [ 1/11] FROM docker.io/nvidia/cuda:12.3.2-cudnn9-runtime-ubunt  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 7.29MB                                        0.1s
#  => [ 2/11] RUN apt-get update && apt-get install -y --no-install-recomm  77.0s
#  => [ 3/11] RUN python3.11 -m venv /opt/venv                               2.0s
#  => [ 4/11] RUN pip install --no-cache-dir --upgrade pip                   1.6s
#  => [ 5/11] RUN pip install --no-cache-dir torch torchvision torchaudio  120.7s
#  => [ 6/11] RUN pip install --no-cache-dir jupyter notebook jupyterlab    13.2s
#  => [ 7/11] WORKDIR /app                                                   0.0s
#  => [ 8/11] COPY . /app                                                    6.7s
#  => [ 9/11] RUN pip3 install gpt4all                                       2.1s
#  => [10/11] COPY requirements.txt /app/requirements.txt                    0.0s
#  => [11/11] RUN pip install --no-cache-dir -r /app/requirements.txt        1.3s
#  => exporting to image                                                    11.4s
#  => => exporting layers                                                   11.4s
# [+] Building 238.4s (16/17)                                      docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  2.0s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [ 1/11] FROM docker.io/nvidia/cuda:12.3.2-cudnn9-runtime-ubunt  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 7.29MB                                        0.1s
#  => [ 2/11] RUN apt-get update && apt-get install -y --no-install-recomm  77.0s
#  => [ 3/11] RUN python3.11 -m venv /opt/venv                               2.0s
#  => [ 4/11] RUN pip install --no-cache-dir --upgrade pip                   1.6s
#  => [ 5/11] RUN pip install --no-cache-dir torch torchvision torchaudio  120.7s
#  => [ 6/11] RUN pip install --no-cache-dir jupyter notebook jupyterlab    13.2s
#  => [ 7/11] WORKDIR /app                                                   0.0s
#  => [ 8/11] COPY . /app                                                    6.7s
#  => [ 9/11] RUN pip3 install gpt4all                                       2.1s
#  => [10/11] COPY requirements.txt /app/requirements.txt                    0.0s
#  => [11/11] RUN pip install --no-cache-dir -r /app/requirements.txt        1.3s
#  => exporting to image                                                    11.6s
#  => => exporting layers                                                   11.6s
# [+] Building 238.4s (16/17)                                      docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  2.0s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [ 1/11] FROM docker.io/nvidia/cuda:12.3.2-cudnn9-runtime-ubunt  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 7.29MB                                        0.1s
#  => [ 2/11] RUN apt-get update && apt-get install -y --no-install-recomm  77.0s
#  => [ 3/11] RUN python3.11 -m venv /opt/venv                               2.0s
#  => [ 4/11] RUN pip install --no-cache-dir --upgrade pip                   1.6s
#  => [ 5/11] RUN pip install --no-cache-dir torch torchvision torchaudio  120.7s
#  => [ 6/11] RUN pip install --no-cache-dir jupyter notebook jupyterlab    13.2s
#  => [ 7/11] WORKDIR /app                                                   0.0s
#  => [ 8/11] COPY . /app                                                    6.7s
#  => [ 9/11] RUN pip3 install gpt4all                                       2.1s
#  => [10/11] COPY requirements.txt /app/requirements.txt                    0.0s
#  => [11/11] RUN pip install --no-cache-dir -r /app/requirements.txt        1.3s
#  => exporting to image                                                    11.6s
#  => => exporting layers                                                   11.6s
# [+] Building 238.5s (17/17) FINISHED                             docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.47kB                                     0.0s
#  => [internal] load metadata for docker.io/nvidia/cuda:12.3.2-cudnn9-runt  2.0s
#  => [auth] nvidia/cuda:pull token for registry-1.docker.io                 0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [ 1/11] FROM docker.io/nvidia/cuda:12.3.2-cudnn9-runtime-ubunt  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 7.29MB                                        0.1s
#  => [ 2/11] RUN apt-get update && apt-get install -y --no-install-recomm  77.0s
#  => [ 3/11] RUN python3.11 -m venv /opt/venv                               2.0s
#  => [ 4/11] RUN pip install --no-cache-dir --upgrade pip                   1.6s
#  => [ 5/11] RUN pip install --no-cache-dir torch torchvision torchaudio  120.7s
#  => [ 6/11] RUN pip install --no-cache-dir jupyter notebook jupyterlab    13.2s
#  => [ 7/11] WORKDIR /app                                                   0.0s
#  => [ 8/11] COPY . /app                                                    6.7s
#  => [ 9/11] RUN pip3 install gpt4all                                       2.1s
#  => [10/11] COPY requirements.txt /app/requirements.txt                    0.0s
#  => [11/11] RUN pip install --no-cache-dir -r /app/requirements.txt        1.3s
#  => exporting to image                                                    11.6s
#  => => exporting layers                                                   11.6s
#  => => writing image sha256:d8f6299a547375cf4496e215357f9c22de61a052017f5  0.0s
#  => => naming to docker.io/pakkinlau/gpt4all-wrapper                       0.0s

# %% [markdown]
# # Building an image (6 March 2024): Spent 4 minutes.
